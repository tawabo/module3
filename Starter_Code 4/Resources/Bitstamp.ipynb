# %%
import pandas as pd
from pathlib import Path

# %%
csvpath = Path("../Resources/bitstamp.csv")

# %%
bitstamp_df = pd.read_csv(csvpath, index_col="Timestamp", parse_dates=True, infer_datetime_format=True)

# %%
bitstamp_df.head()
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  $13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  $13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  $13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  $13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   $13620.0    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# 2018-01-01 00:02:00   1152.144036    13610.136247
# 2018-01-01 00:03:00  97856.416478    13623.361128
# 2018-01-01 00:04:00  14582.660932    13632.923329

# %%
bitstamp_df.tail()
# Out:
#                         Open     High      Low     Close  BTC Volume  \
# Timestamp
# 2018-03-31 23:55:00  6935.01  6939.07  6922.56  $6922.56    1.044354
# 2018-03-31 23:56:00  6922.02  6922.02  6918.00  $6920.32    3.069539
# 2018-03-31 23:57:00  6920.33  6936.42  6920.33  $6934.72   28.239049
# 2018-03-31 23:58:00  6927.65  6929.42  6927.65  $6927.65    0.839507
# 2018-03-31 23:59:00  6929.98  6929.98  6928.00  $6928.01    0.209363
#
#                         USD Volume  Weighted Price
# Timestamp
# 2018-03-31 23:55:00    7240.034602     6932.550078
# 2018-03-31 23:56:00   21245.076275     6921.260233
# 2018-03-31 23:57:00  195789.408220     6933.286106
# 2018-03-31 23:58:00    5817.007705     6929.080007
# 2018-03-31 23:59:00    1450.735763     6929.289993

# %%
bitstamp_df.isnull()
# Out:
#                       Open   High    Low  Close  BTC Volume  USD Volume  \
# Timestamp
# 2018-01-01 00:00:00  False  False  False  False       False       False
# 2018-01-01 00:01:00  False  False  False  False       False       False
# 2018-01-01 00:02:00  False  False  False  False       False       False
# 2018-01-01 00:03:00  False  False  False  False       False       False
# 2018-01-01 00:04:00  False  False  False  False       False       False
# ...                    ...    ...    ...    ...         ...         ...
# 2018-03-31 23:55:00  False  False  False  False       False       False
# 2018-03-31 23:56:00  False  False  False  False       False       False
# 2018-03-31 23:57:00  False  False  False  False       False       False
# 2018-03-31 23:58:00  False  False  False  False       False       False
# 2018-03-31 23:59:00  False  False  False  False       False       False
#
#                      Weighted Price
# Timestamp
# 2018-01-01 00:00:00           False
# ...

# %%
bitstamp_df.isnull().sum()
# Out:
# Open              473
# High              473
# Low               473
# Close               0
# BTC Volume        473
# USD Volume        473
# Weighted Price    473
# dtype: int64

# %%
bitstamp_df = bitstamp_df.fillna(0)

# %%
bitstamp_df.isnull().sum()
# Out:
# Open              0
# High              0
# Low               0
# Close             0
# BTC Volume        0
# USD Volume        0
# Weighted Price    0
# dtype: int64

# %%
bitstamp_df["Close"] = bitstamp_df["Close"].str.replace("$","")
# Out:
# /Users/abdulhamidi/opt/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
bitstamp_df
# Out:
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   13620.0    1.069665
# ...                       ...       ...       ...       ...         ...
# 2018-03-31 23:55:00   6935.01   6939.07   6922.56   6922.56    1.044354
# 2018-03-31 23:56:00   6922.02   6922.02   6918.00   6920.32    3.069539
# 2018-03-31 23:57:00   6920.33   6936.42   6920.33   6934.72   28.239049
# 2018-03-31 23:58:00   6927.65   6929.42   6927.65   6927.65    0.839507
# 2018-03-31 23:59:00   6929.98   6929.98   6928.00   6928.01    0.209363
#
#                         USD Volume  Weighted Price
# Timestamp
# ...

# %%
bitstamp_df["Close"] = bitstamp_df["Close"].astype('float')

# %%
bitstamp_df.dtypes
# Out:
# Open              float64
# High              float64
# Low               float64
# Close             float64
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object

# %%
bitstamp_df.duplicated()
bitstamp_df.drop_duplicates()
# Out:
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00  13620.00    1.069665
# ...                       ...       ...       ...       ...         ...
# 2018-03-31 23:55:00   6935.01   6939.07   6922.56   6922.56    1.044354
# 2018-03-31 23:56:00   6922.02   6922.02   6918.00   6920.32    3.069539
# 2018-03-31 23:57:00   6920.33   6936.42   6920.33   6934.72   28.239049
# 2018-03-31 23:58:00   6927.65   6929.42   6927.65   6927.65    0.839507
# 2018-03-31 23:59:00   6929.98   6929.98   6928.00   6928.01    0.209363
#
#                         USD Volume  Weighted Price
# Timestamp
# ...

# %%
bitstamp_df.duplicated().sum()
# Out:
# 472

# %%
bitstamp_slice = bitstamp_df.iloc[: , 3]

# %%
bitstamp_slice.head()
# Out:
# Timestamp
# 2018-01-01 00:00:00    13646.48
# 2018-01-01 00:01:00    13658.75
# 2018-01-01 00:02:00    13610.22
# 2018-01-01 00:03:00    13639.09
# 2018-01-01 00:04:00    13620.00
# Name: Close, dtype: float64

# %%
bitstamp_slice.describe()
# Out:
# count    129067.000000
# mean      10459.842453
# std        2315.976088
# min        5944.000000
# 25%        8613.370000
# 50%       10145.950000
# 75%       11444.810000
# max       17234.980000
# Name: Close, dtype: float64

# %%
bitstamp_slice.plot(figsize=(20, 10), title="Closing Price of BTC on BTS", color="red", xlabel="date", ylabel="Closing Price", rot=45)
# Out:
# <AxesSubplot:title={'center':'Closing Price of BTC on BTS'}, xlabel='date', ylabel='Closing Price'>

# %%
coinbase_df

# %%
bitstamp_slice2.head()
# Out:
# Timestamp
# 2018-01-01 00:00:00    13681.04
# 2018-01-01 00:01:00    13646.48
# 2018-01-01 00:02:00    13616.93
# 2018-01-01 00:03:00    13610.27
# 2018-01-01 00:04:00    13635.35
# Name: Open, dtype: float64

# %%
bitstamp_slice.plot(legend=True, figsize=(20, 10), title="Daily Price flucuation BTC on BTS", color="red", xlabel="date", ylabel="Closing Price", label="Close")
bitstamp_slice2.plot(legend=True, figsize=(20, 10), color="blue", label="open")
# Out:
# <AxesSubplot:title={'center':'Daily Price flucuation BTC on BTS'}, xlabel='Timestamp', ylabel='Closing Price'>
